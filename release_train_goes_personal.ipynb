# %% [markdown]
# # Train the original REleASE and HESPERIA matrices
#
# This notebook now trains two deterministic forecasting paths:
# - the original 2007 REleASE rise-parameter matrix
# - the HESPERIA 30/60/90-minute ensemble matrix library
#
# The original release path uses a 60-minute rise parameter and a 50x50 log-log lookup table.
# The HESPERIA path trains multiple window-specific matrices for the three-matrix voter.

# %% [markdown]
# ## Import Required Libraries
#
# Load the libraries used for time-series preprocessing, binning, and JSON export.

# %%
import json
from dataclasses import dataclass
from pathlib import Path
from typing import Dict, List, Sequence, Tuple

import numpy as np
import pandas as pd

# %% [markdown]
# ## Configure Training Parameters
#
# Set the input columns, window sizes, bin counts, and output path for the trained matrix.

# %%
# Train on every historical CSV in gsep_ts, but skip the event list file.
GSEP_ROOT = Path("/Users/ran/cs/oires/data/raw/gsep_ts")
CSV_PATHS = sorted(
    str(path)
    for path in GSEP_ROOT.rglob("*.csv")
    if path.name.lower() != "gsep_list.csv"
)
TIME_COL = "time_tag"
ELECTRON_COL = "e2_flux_ic"
PROTON_COL = "p3_flux_ic"  # Target proton channel for training.
LEAD_MINUTES = 60
RELEASE_LOOKBACK_MINUTES = 60
HESPERIA_WINDOW_MINUTES = [30, 60, 90]
BIN_SIZES = [25, 35, 45]
MIN_SAMPLES_PER_CELL = 30
OUTPUT_DIR = Path("oneoutput")
RELEASE_MATRIX_JSON = OUTPUT_DIR / "trained_release_matrix.json"
print(f"Historical training files: {len(CSV_PATHS)}")
print(f"Excluded accuracy-check file: {GSEP_ROOT / 'GSEP_List.csv'}")
print(f"Output directory: {OUTPUT_DIR}")
print(f"HESPERIA windows: {HESPERIA_WINDOW_MINUTES}")
print(f"Bin sizes: {BIN_SIZES}")
print(f"Original release matrix: {RELEASE_MATRIX_JSON}")
# Out:
# Historical training files: 433
# Excluded accuracy-check file: /Users/ran/cs/oires/data/raw/gsep_ts/GSEP_List.csv
# Output directory: oneoutput
# HESPERIA windows: [30, 60, 90]
# Bin sizes: [25, 35, 45]
# Original release matrix: oneoutput/trained_release_matrix.json

# %% [markdown]
# ## Helper Functions
#
# Define the preprocessing, binning, and matrix-building helpers used by the trainer.

# %%
@dataclass
class TrainingRow:
    intensity: float
    delta: float
    target_proton: float


def read_series(csv_path: Path, time_col: str, electron_col: str, proton_col: str) -> pd.DataFrame:
    df = pd.read_csv(csv_path)
    for col in (time_col, electron_col, proton_col):
        if col not in df.columns:
            raise ValueError(f"Missing column '{col}' in {csv_path}")

    out = df[[time_col, electron_col, proton_col]].copy()
    out[time_col] = pd.to_datetime(out[time_col], errors="coerce")
    out[electron_col] = pd.to_numeric(out[electron_col], errors="coerce")
    out[proton_col] = pd.to_numeric(out[proton_col], errors="coerce")
    out = out.dropna().sort_values(time_col).reset_index(drop=True)
    out.columns = ["time", "electron", "proton"]
    return out


def infer_cadence_seconds(times: pd.Series) -> float:
    if len(times) < 2:
        return 300.0
    diffs = times.diff().dropna().dt.total_seconds().to_numpy(dtype=float)
    if len(diffs) == 0:
        return 300.0
    return float(np.nanmedian(diffs))


def remove_background_gcr(values: np.ndarray, window_points: int) -> np.ndarray:
    window_points = max(1, window_points)
    s = pd.Series(values)
    background = s.rolling(window=window_points, min_periods=1).median()
    return (s - background).clip(lower=0.0).to_numpy(dtype=float)


def build_training_rows_for_file(
    df: pd.DataFrame,
    lead_minutes: int,
    delta_window_minutes: int,
) -> List[TrainingRow]:
    cadence_seconds = infer_cadence_seconds(df["time"])
    bg_window_points = max(3, int(round(3600.0 / max(cadence_seconds, 1.0))))
    cleaned_electron = remove_background_gcr(df["electron"].to_numpy(dtype=float), bg_window_points)

    delta_points = max(1, int(round((delta_window_minutes * 60.0) / max(cadence_seconds, 1.0))))
    lead_points = max(1, int(round((lead_minutes * 60.0) / max(cadence_seconds, 1.0))))

    proton = df["proton"].to_numpy(dtype=float)
    rows: List[TrainingRow] = []

    upper = len(df) - lead_points
    for i in range(delta_points, upper):
        intensity = float(cleaned_electron[i])
        delta = float(cleaned_electron[i] - cleaned_electron[i - delta_points])
        target = float(proton[i + lead_points])
        if np.isfinite(intensity) and np.isfinite(delta) and np.isfinite(target):
            rows.append(TrainingRow(intensity=intensity, delta=delta, target_proton=target))

    return rows


def safe_quantile_edges(values: np.ndarray, n_bins: int) -> np.ndarray:
    if len(values) == 0:
        raise ValueError("No values available for binning")

    qs = np.linspace(0.0, 1.0, n_bins + 1)
    edges = np.quantile(values, qs)
    edges = np.unique(edges)

    if len(edges) < 2:
        lo = float(values.min())
        hi = float(values.max())
        if hi <= lo:
            hi = lo + 1.0
        edges = np.linspace(lo, hi, n_bins + 1)

    if len(edges) - 1 < n_bins:
        lo = float(values.min())
        hi = float(values.max())
        if hi <= lo:
            hi = lo + 1.0
        edges = np.linspace(lo, hi, n_bins + 1)

    edges[0] = edges[0] - 1e-9
    edges[-1] = edges[-1] + 1e-9
    return edges


def cell_confidence(values: Sequence[float], min_samples_per_cell: int) -> float:
    n = len(values)
    if n == 0:
        return 0.0

    n_score = min(1.0, n / float(max(1, min_samples_per_cell)))
    vals = np.asarray(values, dtype=float)
    med = float(np.median(vals))
    q25 = float(np.percentile(vals, 25))
    q75 = float(np.percentile(vals, 75))
    iqr = q75 - q25
    scale = max(abs(med), 1.0)
    stability = max(0.0, 1.0 - min(1.0, iqr / (2.0 * scale)))
    return float(max(0.0, min(1.0, n_score * stability)))

# %% [markdown]
# ## Build the Delta Matrix
#
# Load the CSVs, generate training rows, bin the feature space, and compute the per-cell proton targets.

# %%
def build_delta_matrix(
    rows: Sequence[TrainingRow],
    intensity_bins: int,
    delta_bins: int,
    min_samples_per_cell: int,
) -> List[Dict[str, float]]:
    if not rows:
        raise ValueError("No training rows were produced. Check columns and data length.")

    intensity = np.array([r.intensity for r in rows], dtype=float)
    delta = np.array([r.delta for r in rows], dtype=float)
    target = np.array([r.target_proton for r in rows], dtype=float)

    i_edges = safe_quantile_edges(intensity, intensity_bins)
    d_edges = safe_quantile_edges(delta, delta_bins)

    i_idx = np.digitize(intensity, i_edges[1:-1], right=False)
    d_idx = np.digitize(delta, d_edges[1:-1], right=False)

    cell_values: Dict[Tuple[int, int], List[float]] = {}
    for ii, dd, tt in zip(i_idx, d_idx, target):
        key = (int(ii), int(dd))
        cell_values.setdefault(key, []).append(float(tt))

    global_median = float(np.median(target))
    matrix: List[Dict[str, float]] = []

    for ii in range(intensity_bins):
        for dd in range(delta_bins):
            vals = cell_values.get((ii, dd), [])
            target_peak = float(np.median(vals)) if vals else global_median
            conf = cell_confidence(vals, min_samples_per_cell=min_samples_per_cell)
            matrix.append(
                {
                    "intensity_min": float(i_edges[ii]),
                    "intensity_max": float(i_edges[ii + 1]),
                    "delta_min": float(d_edges[dd]),
                    "delta_max": float(d_edges[dd + 1]),
                    "target_peak_pfu": target_peak,
                    "p30_peak_pfu": target_peak,
                    "confidence": conf,
                }
            )

    return matrix

# %% [markdown]
# ## Run Training Via CLI and Save JSON (Per Bin)
#
# Call `train_delta_matrix.py` directly for each bin size in `BIN_SIZES`.
#
# Each run writes to a bin-specific folder, for example `oneoutput/bin_25`, and stores a trained matrix JSON there.

# %%
import subprocess

RELEASE_TRAIN_SCRIPT = Path("/Users/ran/cs/6850/project/train_release_matrix.py")
HESPERIA_TRAIN_SCRIPT = Path("/Users/ran/cs/6850/project/train_delta_matrix.py")

release_train_command = [
    "python",
    str(RELEASE_TRAIN_SCRIPT),
    *CSV_PATHS,
    "--time-col",
    TIME_COL,
    "--electron-col",
    ELECTRON_COL,
    "--proton-col",
    PROTON_COL,
    "--lead-minutes",
    str(LEAD_MINUTES),
    "--lookback-minutes",
    str(RELEASE_LOOKBACK_MINUTES),
    "--intensity-bins",
    "50",
    "--rise-bins",
    "50",
    "--min-samples-per-cell",
    str(MIN_SAMPLES_PER_CELL),
    "--out-json",
    str(RELEASE_MATRIX_JSON),
]

print("Running:")
print(" ".join(release_train_command))
completed_release_train = subprocess.run(release_train_command, capture_output=True, text=True, check=False)
print("Return code:", completed_release_train.returncode)
print(completed_release_train.stdout)
print(completed_release_train.stderr)
if completed_release_train.returncode != 0:
    raise RuntimeError("train_release_matrix.py failed; see output above")

if not RELEASE_MATRIX_JSON.exists():
    raise RuntimeError(f"Expected release matrix not found: {RELEASE_MATRIX_JSON}")

print(f"Wrote original REleASE matrix: {RELEASE_MATRIX_JSON}")

TRAINED_BIN_CONFIGS = []
for bin_size in BIN_SIZES:
    bin_dir = OUTPUT_DIR / f"bin_{bin_size}"
    bin_dir.mkdir(parents=True, exist_ok=True)

    train_command = [
        "python",
        str(HESPERIA_TRAIN_SCRIPT),
        *CSV_PATHS,
        "--time-col",
        TIME_COL,
        "--electron-col",
        ELECTRON_COL,
        "--proton-col",
        PROTON_COL,
        "--instrument",
        "GOES",
        "--lead-minutes",
        str(LEAD_MINUTES),
        "--sliding-window-minutes",
        *[str(window) for window in HESPERIA_WINDOW_MINUTES],
        "--intensity-bins",
        str(bin_size),
        "--delta-bins",
        str(bin_size),
        "--min-samples-per-cell",
        str(MIN_SAMPLES_PER_CELL),
        "--out-dir",
        str(bin_dir),
    ]

    print("Running:")
    print(" ".join(train_command))
    completed_train = subprocess.run(train_command, capture_output=True, text=True, check=False)
    print("Return code:", completed_train.returncode)
    print(completed_train.stdout)
    print(completed_train.stderr)

    if completed_train.returncode != 0:
        raise RuntimeError(f"train_delta_matrix.py failed for bin {bin_size}; see output above")

    matrix_library_json = bin_dir / "matrix_index_goes.json"
    if not matrix_library_json.exists():
        raise RuntimeError(f"Expected HESPERIA matrix library not found: {matrix_library_json}")

    TRAINED_BIN_CONFIGS.append(
        {
            "bin_size": int(bin_size),
            "bin_dir": str(bin_dir),
            "matrix_library_json": str(matrix_library_json.resolve()),
            "release_matrix_json": str(RELEASE_MATRIX_JSON.resolve()),
        }
    )

print(f"Completed training for {len(TRAINED_BIN_CONFIGS)} bin settings")
# Out:
# Running:
# python /Users/ran/cs/6850/project/train_release_matrix.py /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1986-02-03_21-25.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1986-02-05_05-50.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1986-02-05_23-00.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1986-02-07_01-00.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1986-02-10_09-00.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1986-02-14_02-20.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1986-02-16_14-20.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1986-03-06_06-25.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1986-05-04_01-00.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1987-05-29_05-25.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1987-11-07_19-50.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1987-12-29_14-15.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-01-02_15-55.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-03-25_10-50.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-06-14_17-20.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-06-29_23-25.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-07-19_19-00.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-07-26_09-40.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-08-25_01-55.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-09-27_09-20.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-10-04_20-55.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-10-11_18-45.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-10-13_10-00.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-11-08_01-50.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-11-13_13-30.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-12-12_23-10.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-12-14_00-10.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-12-15_21-40.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-12-26_20-55.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-12-28_12-45.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-01-04_09-15.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-03-08_05-55.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-03-12_07-25.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-03-17_07-00.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-03-23_08-55.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-04-09_05-00.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-04-11_03-55.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-04-21_17-05.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-05-02_04-50.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-05-04_20-35.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-05-05_18-25.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-05-06_17-10.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-05-19_23-15.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-05-22_06-30.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-06-13_23-10.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-06-18_05-05.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-06-20_09-20.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-06-28_16-45.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-06-29_10-55.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-06-30_08-20.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-07-24_21-35.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-08-12_04-20.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-08-14_18-30.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-08-15_13-30.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-08-16_19-05.csv /Users/ran/cs/oires/data/raw/gsep_ts/ ...
# Return code: 0
# Training rows: 211879
# Matrix cells: 2500
# Wrote: oneoutput/trained_release_matrix.json
#
#
# Wrote original REleASE matrix: oneoutput/trained_release_matrix.json
# Running:
# python /Users/ran/cs/6850/project/train_delta_matrix.py /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1986-02-03_21-25.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1986-02-05_05-50.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1986-02-05_23-00.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1986-02-07_01-00.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1986-02-10_09-00.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1986-02-14_02-20.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1986-02-16_14-20.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1986-03-06_06-25.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1986-05-04_01-00.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1987-05-29_05-25.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1987-11-07_19-50.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1987-12-29_14-15.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-01-02_15-55.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-03-25_10-50.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-06-14_17-20.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-06-29_23-25.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-07-19_19-00.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-07-26_09-40.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-08-25_01-55.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-09-27_09-20.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-10-04_20-55.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-10-11_18-45.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-10-13_10-00.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-11-08_01-50.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-11-13_13-30.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-12-12_23-10.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-12-14_00-10.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-12-15_21-40.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-12-26_20-55.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1988-12-28_12-45.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-01-04_09-15.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-03-08_05-55.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-03-12_07-25.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-03-17_07-00.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-03-23_08-55.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-04-09_05-00.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-04-11_03-55.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-04-21_17-05.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-05-02_04-50.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-05-04_20-35.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-05-05_18-25.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-05-06_17-10.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-05-19_23-15.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-05-22_06-30.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-06-13_23-10.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-06-18_05-05.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-06-20_09-20.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-06-28_16-45.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-06-29_10-55.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-06-30_08-20.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-07-24_21-35.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-08-12_04-20.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-08-14_18-30.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-08-15_13-30.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989
csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-08-15_13-30.csv /Users/ran/cs/oires/data/raw/gsep_ts/gsep_sc22_ts/1989-08-16_19-05.csv /Users/ran/cs/oires/data/raw/gsep_ts/gs ...
# Return code: 0
# [GOES] window=30min training rows: 214477
# [GOES] window=30min matrix cells: 2025
# Wrote: oneoutput/bin_45/matrix_goes_30min.json
# [GOES] window=60min training rows: 211879
# [GOES] window=60min matrix cells: 2025
# Wrote: oneoutput/bin_45/matrix_goes_60min.json
# [GOES] window=90min training rows: 209281
# [GOES] window=90min matrix cells: 2025
# Wrote: oneoutput/bin_45/matrix_goes_90min.json
# Wrote matrix index: oneoutput/bin_45/matrix_index_goes.json
#
#
# Completed training for 3 bin settings

# %% [markdown]
# ## Generate Matrix Graphs
#
# Run the standalone grapher script to create target and confidence heatmaps from the trained matrix JSON.

# %%
import subprocess

GRAPHER_SCRIPT = Path("/Users/ran/cs/6850/project/delta_matrix_grapher.py")

# original RELeASE

bin_size = int(50)
matrix_json = Path(cfg["release_matrix_json"])
target_heatmap_png = f"matrix_target_heatmap_bin_{bin_size}.png"
conf_heatmap_png = f"matrix_confidence_heatmap_bin_{bin_size}.png"

graph_command = [
    "python",
    str(GRAPHER_SCRIPT),
    "--matrix-json",
    str(matrix_json),
    "--out-target-png",
    str(target_heatmap_png),
    "--out-confidence-png",
    str(conf_heatmap_png),
    "--target-field",
    "auto",
    "--title-prefix",
    f"REleASE Delta Matrix (bin={bin_size})",
]

print("Running:")
print(" ".join(graph_command))
completed_graph = subprocess.run(graph_command, capture_output=True, text=True, check=False)
print("Return code:", completed_graph.returncode)
print(completed_graph.stdout)
print(completed_graph.stderr)

# HESPERIA RELeAse



print(TRAINED_BIN_CONFIGS)
for cfg in TRAINED_BIN_CONFIGS:
    bin_size = int(cfg["bin_size"])

    current_bin_dir = Path("oneoutput") / f"bin_{bin_size}"
    current_bin_dir.mkdir(parents=True, exist_ok=True)    

    library_path = Path(cfg["matrix_library_json"])

    with open(library_path, 'r') as f:
        matrix_list = json.load(f)
    for entry in matrix_list:
        matrix_json = Path(entry["matrix_path"])
        sliding_window_minutes = str(entry["sliding_window_minutes"])
        
        target_heatmap_png = current_bin_dir / f"matrix_target_heatmap_bin_{sliding_window_minutes}.png"
        conf_heatmap_png = current_bin_dir / f"matrix_confidence_heatmap_bin_{sliding_window_minutes}.png"

        graph_command = [
            "python",
            str(GRAPHER_SCRIPT),
            "--matrix-json",
            str(matrix_json),
            "--out-target-png",
            str(target_heatmap_png),
            "--out-confidence-png",
            str(conf_heatmap_png),
            "--target-field",
            "auto",
            "--title-prefix",
            f"REleASE Delta Matrix (bin={bin_size})",
        ]

        print("Running:")
        print(" ".join(graph_command))
        completed_graph = subprocess.run(graph_command, capture_output=True, text=True, check=False)
        print("Return code:", completed_graph.returncode)
        print(completed_graph.stdout)
        print(completed_graph.stderr)
# Out:
# Running:
# python /Users/ran/cs/6850/project/delta_matrix_grapher.py --matrix-json /Users/ran/cs/6850/project/oneoutput/trained_release_matrix.json --out-target-png matrix_target_heatmap_bin_50.png --out-confidence-png matrix_confidence_heatmap_bin_50.png --target-field auto --title-prefix REleASE Delta Matrix (bin=50)
# Return code: 0
# Wrote target heatmap: matrix_target_heatmap_bin_50.png
# Wrote confidence heatmap: matrix_confidence_heatmap_bin_50.png
#
#
# [{'bin_size': 25, 'bin_dir': 'oneoutput/bin_25', 'matrix_library_json': '/Users/ran/cs/6850/project/oneoutput/bin_25/matrix_index_goes.json', 'release_matrix_json': '/Users/ran/cs/6850/project/oneoutput/trained_release_matrix.json'}, {'bin_size': 35, 'bin_dir': 'oneoutput/bin_35', 'matrix_library_json': '/Users/ran/cs/6850/project/oneoutput/bin_35/matrix_index_goes.json', 'release_matrix_json': '/Users/ran/cs/6850/project/oneoutput/trained_release_matrix.json'}, {'bin_size': 45, 'bin_dir': 'oneoutput/bin_45', 'matrix_library_json': '/Users/ran/cs/6850/project/oneoutput/bin_45/matrix_index_goes.json', 'release_matrix_json': '/Users/ran/cs/6850/project/oneoutput/trained_release_matrix.json'}]
# Running:
# python /Users/ran/cs/6850/project/delta_matrix_grapher.py --matrix-json oneoutput/bin_25/matrix_goes_30min.json --out-target-png oneoutput/bin_25/matrix_target_heatmap_bin_30.png --out-confidence-png oneoutput/bin_25/matrix_confidence_heatmap_bin_30.png --target-field auto --title-prefix REleASE Delta Matrix (bin=25)
# Return code: 0
# Wrote target heatmap: oneoutput/bin_25/matrix_target_heatmap_bin_30.png
# Wrote confidence heatmap: oneoutput/bin_25/matrix_confidence_heatmap_bin_30.png
#
#
# Running:
# python /Users/ran/cs/6850/project/delta_matrix_grapher.py --matrix-json oneoutput/bin_25/matrix_goes_60min.json --out-target-png oneoutput/bin_25/matrix_target_heatmap_bin_60.png --out-confidence-png oneoutput/bin_25/matrix_confidence_heatmap_bin_60.png --target-field auto --title-prefix REleASE Delta Matrix (bin=25)
# Return code: 0
# Wrote target heatmap: oneoutput/bin_25/matrix_target_heatmap_bin_60.png
# Wrote confidence heatmap: oneoutput/bin_25/matrix_confidence_heatmap_bin_60.png
#
#
# Running:
# python /Users/ran/cs/6850/project/delta_matrix_grapher.py --matrix-json oneoutput/bin_25/matrix_goes_90min.json --out-target-png oneoutput/bin_25/matrix_target_heatmap_bin_90.png --out-confidence-png oneoutput/bin_25/matrix_confidence_heatmap_bin_90.png --target-field auto --title-prefix REleASE Delta Matrix (bin=25)
# Return code: 0
# Wrote target heatmap: oneoutput/bin_25/matrix_target_heatmap_bin_90.png
# Wrote confidence heatmap: oneoutput/bin_25/matrix_confidence_heatmap_bin_90.png
#
#
# Running:
# python /Users/ran/cs/6850/project/delta_matrix_grapher.py --matrix-json oneoutput/bin_35/matrix_goes_30min.json --out-target-png oneoutput/bin_35/matrix_target_heatmap_bin_30.png --out-confidence-png oneoutput/bin_35/matrix_confidence_heatmap_bin_30.png --target-field auto --title-prefix REleASE Delta Matrix (bin=35)
# Return code: 0
# Wrote target heatmap: oneoutput/bin_35/matrix_target_heatmap_bin_30.png
# Wrote confidence heatmap: oneoutput/bin_35/matrix_confidence_heatmap_bin_30.png
#
#
# Running:
# python /Users/ran/cs/6850/project/delta_matrix_grapher.py --matrix-json oneoutput/bin_35/matrix_goes_60min.json --out-target-png oneoutput/bin_35/matrix_target_heatmap_bin_60.png --out-confidence-png oneoutput/bin_35/matrix_confidence_heatmap_bin_60.png --target-field auto --title-prefix REleASE Delta Matrix (bin=35)
# Return code: 0
# Wrote target heatmap: oneoutput/bin_35/matrix_target_heatmap_bin_60.png
# Wrote confidence heatmap: oneoutput/bin_35/matrix_confidence_heatmap_bin_60.png
#
#
# Running:
# python /Users/ran/cs/6850/project/delta_matrix_grapher.py --matrix-json oneoutput/bin_35/matrix_goes_90min.json --out-target-png oneoutput/bin_35/matrix_target_heatmap_bin_90.png --out-confidence-png oneoutput/bin_35/matrix_confidence_heatmap_bin_90.png --target-field auto --title-prefix REleASE Delta Matrix (bin=35)
# Return code: 0
# Wrote target heatmap: oneoutput/bin_35/matrix_target_heatmap_bin_90.png
# Wrote confidence heatmap: oneoutput/bin_35/matrix_confidence_heatmap_bin_90.png
#
#
# Running:
# python /Users/ran/cs/6850/project/delta_matrix_grapher.py --matrix-json oneoutput/bin_45/matrix_goes_30min.json --out-target-png oneoutput/bin_45/matrix_target_heatmap_bin_30.png --out-confidence-png oneoutput/bin_45/matrix_confidence_heatmap_bin_30.png --target-field auto --title-prefix REleASE Delta Matrix (bin=45)
# Return code: 0
# Wrote target heatmap: oneoutput/bin_45/matrix_target_heatmap_bin_30.png
# Wrote confidence heatmap: oneoutput/bin_45/matrix_confidence_heatmap_bin_30.png
#
#
# Running:
# python /Users/ran/cs/6850/project/delta_matrix_grapher.py --matrix-json oneoutput/bin_45/matrix_goes_60min.json --out-target-png oneoutput/bin_45/matrix_target_heatmap_bin_60.png --out-confidence-png oneoutput/bin_45/matrix_confidence_heatmap_bin_60.png --target-field auto --title-prefix REleASE Delta Matrix (bin=45)
# Return code: 0
# Wrote target heatmap: oneoutput/bin_45/matrix_target_heatmap_bin_60.png
# Wrote confidence heatmap: oneoutput/bin_45/matrix_confidence_heatmap_bin_60.png
#
#
# Running:
# python /Users/ran/cs/6850/project/delta_matrix_grapher.py --matrix-json oneoutput/bin_45/matrix_goes_90min.json --out-target-png oneoutput/bin_45/matrix_target_heatmap_bin_90.png --out-confidence-png oneoutput/bin_45/matrix_confidence_heatmap_bin_90.png --target-field auto --title-prefix REleASE Delta Matrix (bin=45)
# Return code: 0
# Wrote target heatmap: oneoutput/bin_45/matrix_target_heatmap_bin_90.png
# Wrote confidence heatmap: oneoutput/bin_45/matrix_confidence_heatmap_bin_90.png

# %% [markdown]
# ## Run RELease With Trained Matrices (Per Bin)
#
# Run RELease for every CSV path and every bin size.
#
# Each bin setting writes to its own output folder, then runs hit/miss comparison to enable side-by-side evaluation.

# %%
RELEASE_SCRIPT = Path("/Users/ran/cs/6850/project/RELease.py")
COMPARE_SCRIPT = Path("/Users/ran/cs/6850/project/compare_hit_miss.py")

RELEASE_INPUT_PATHS = list(CSV_PATHS)
RELEASE_INSTRUMENT = "GOES"
GSEP_LIST_CSV = GSEP_ROOT / "GSEP_List.csv"
ORIGINAL_RELEASE_OUTPUT_DIR = OUTPUT_DIR / "original_release_outputs"

print(f"Release script: {RELEASE_SCRIPT}")
print(f"Compare script: {COMPARE_SCRIPT}")
print(f"Total RELease inputs: {len(RELEASE_INPUT_PATHS)}")
print(f"Original release output dir: {ORIGINAL_RELEASE_OUTPUT_DIR}")
print(f"HESPERIA run configs: {len(TRAINED_BIN_CONFIGS)}")
for cfg in TRAINED_BIN_CONFIGS:
    print(
        f" - bin={cfg['bin_size']}: matrix_library={cfg['matrix_library_json']} -> output_dir={cfg['bin_dir']}"
    )
# Out:
# Release script: /Users/ran/cs/6850/project/RELease.py
# Compare script: /Users/ran/cs/6850/project/compare_hit_miss.py
# Total RELease inputs: 433
# Original release output dir: oneoutput/original_release_outputs
# HESPERIA run configs: 3
#  - bin=25: matrix_library=/Users/ran/cs/6850/project/oneoutput/bin_25/matrix_index_goes.json -> output_dir=oneoutput/bin_25
#  - bin=35: matrix_library=/Users/ran/cs/6850/project/oneoutput/bin_35/matrix_index_goes.json -> output_dir=oneoutput/bin_35
#  - bin=45: matrix_library=/Users/ran/cs/6850/project/oneoutput/bin_45/matrix_index_goes.json -> output_dir=oneoutput/bin_45

# %%
import subprocess

comparison_summaries = []

# # Run the original 2007 REleASE path once against the full CSV set.
ORIGINAL_RELEASE_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
print("=== Running original REleASE batch ===")
for csv_path in RELEASE_INPUT_PATHS:
    csv_path = Path(csv_path)
    try:
        rel_name = csv_path.relative_to(GSEP_ROOT).with_suffix("").as_posix().replace("/", "__")
    except ValueError:
        rel_name = csv_path.stem

    out_json_path = ORIGINAL_RELEASE_OUTPUT_DIR / f"release_{rel_name}.json"
    release_command = [
        "python",
        str(RELEASE_SCRIPT),
        "--model",
        "original-release",
        "--electron-csv",
        str(csv_path),
        "--electron-time-col",
        TIME_COL,
        "--electron-flux-col",
        ELECTRON_COL,
        "--proton-csv",
        str(csv_path),
        "--proton-time-col",
        TIME_COL,
        "--proton-gt10-col",
        PROTON_COL,
        "--release-matrix-json",
        str(RELEASE_MATRIX_JSON),
        "--forecast-lead-minutes",
        str(LEAD_MINUTES),
        "--paper-warning-trigger-pfu",
        "10",
        "--release-warning-trigger-pfu",
        "10",
        "--out-json",
        str(out_json_path),
    ]

    completed = subprocess.run(release_command, capture_output=True, text=True, check=False)
    print(f"[original] {csv_path.name} -> rc={completed.returncode}")
    if completed.returncode != 0:
        print(completed.stdout)
        print(completed.stderr)

original_compare_csv = ORIGINAL_RELEASE_OUTPUT_DIR / "release_hit_miss_comparison.csv"
original_compare_summary_json = ORIGINAL_RELEASE_OUTPUT_DIR / "release_hit_miss_summary.json"
original_compare_command = [
    "python",
    str(COMPARE_SCRIPT),
    "--gsep-list-csv",
    str(GSEP_LIST_CSV),
    "--release-output-dir",
    str(ORIGINAL_RELEASE_OUTPUT_DIR),
    "--out-csv",
    str(original_compare_csv),
    "--out-summary-json",
    str(original_compare_summary_json),
]
completed_original_compare = subprocess.run(original_compare_command, capture_output=True, text=True, check=False)
print(f"[original] compare rc={completed_original_compare.returncode}")
print(completed_original_compare.stdout)
if completed_original_compare.returncode != 0:
    print(completed_original_compare.stderr)

if original_compare_summary_json.exists():
    summary_payload = json.loads(original_compare_summary_json.read_text())
    comparison_summaries.append(
        {
            "label": "original-release",
            "summary_json": str(original_compare_summary_json),
            "counts": summary_payload.get("counts", {}),
            "rates": summary_payload.get("rates", {}),
        }
    )

# Run the HESPERIA three-matrix voter for each trained bin size.
import subprocess
import shutil
import os
import json
from pathlib import Path

# Ensure paths are absolute for execution
PROJECT_ROOT = Path("/Users/ran/cs/6850/project").resolve()
comparison_summaries = []

# --- Run the HESPERIA three-matrix voter for each trained bin size ---

for cfg in TRAINED_BIN_CONFIGS:
    bin_size = int(cfg["bin_size"])
    
    # 1. Define Output Directory for this bin
    base_out_dir = PROJECT_ROOT / f"oneoutput/bin_{bin_size}"
    base_out_dir.mkdir(parents=True, exist_ok=True)

    # 2. PROXY LIBRARY FIX:
    # The JSON contains relative paths like "oneoutput/bin_25/...".
    # We copy the library to the PROJECT_ROOT so those paths align with the script.
    original_library = PROJECT_ROOT / cfg["matrix_library_json"]    
    proxy_library = PROJECT_ROOT / f"proxy_lib_{bin_size}.json"
    shutil.copy(original_library, proxy_library)

    # Debugging Information
    print(f"\n=== Processing Bin Size: {bin_size} ===")
    print(f"DEBUG: Current Working Directory: {os.getcwd()}")
    print(f"DEBUG: Using Proxy Library: {proxy_library}")
    print(f"DEBUG: Output Directory: {base_out_dir}")

    # 3. Run Release Script for each input CSV
    for csv_path_raw in RELEASE_INPUT_PATHS:
        csv_path = Path(csv_path_raw)
        try:
            rel_name = csv_path.relative_to(GSEP_ROOT).with_suffix("").as_posix().replace("/", "__")
        except (ValueError, NameError):
            rel_name = csv_path.stem

        out_json_path = base_out_dir / f"release_{rel_name}.json"
        
        release_command = [
            "python",
            str(RELEASE_SCRIPT),
            "--model", "hesperia-release",
            "--instrument", RELEASE_INSTRUMENT,
            "--delta-matrix-library-json", str(proxy_library), # Use proxy here
            "--ensemble-window-minutes", "30", "60", "90",
            "--electron-csv", str(csv_path),
            "--electron-time-col", TIME_COL,
            "--electron-flux-col", ELECTRON_COL,
            "--proton-csv", str(csv_path),
            "--proton-time-col", TIME_COL,
            "--proton-gt10-col", PROTON_COL,
            "--forecast-lead-minutes", str(LEAD_MINUTES),
            "--paper-hazard-pfu", "20",
            "--paper-warning-trigger-pfu", "10",
            "--out-json", str(out_json_path),
        ]

        completed = subprocess.run(release_command, capture_output=True, text=True, check=False)
        
        if completed.returncode != 0:
            print(f"[bin={bin_size}] FAIL: {csv_path.name}")
            print(completed.stderr)
        else:
            print(f"[bin={bin_size}] SUCCESS: {csv_path.name}")

    # 4. Run Comparison Script for this bin folder
    compare_csv = base_out_dir / f"release_hit_miss_comparison_bin_{bin_size}.csv"
    compare_summary_json = base_out_dir / f"release_hit_miss_summary_bin_{bin_size}.json"
    
    compare_command = [
        "python",
        str(COMPARE_SCRIPT),
        "--gsep-list-csv", str(GSEP_LIST_CSV),
        "--release-output-dir", str(base_out_dir),
        "--out-csv", str(compare_csv),
        "--out-summary-json", str(compare_summary_json),
    ]

    completed_compare = subprocess.run(compare_command, capture_output=True, text=True, check=False)
    print(f"=== Bin {bin_size} Comparison Finished (rc={completed_compare.returncode}) ===")

    # 5. Collect Results for Final Summary Table
    if compare_summary_json.exists():
        try:
            summary_payload = json.loads(compare_summary_json.read_text())
            comparison_summaries.append({
                "label": f"bin={bin_size}",
                "counts": summary_payload.get("counts", {}),
                "rates": summary_payload.get("rates", {}),
            })
        except json.JSONDecodeError:
            print(f"Warning: Could not parse {compare_summary_json}")

    # Cleanup proxy file
    if proxy_library.exists():
        proxy_library.unlink()

# --- Final Comparison Table Printout ---
print("\n" + "="*60)
print(f"{'MODEL LABEL':<15} | {'HITS':<6} | {'MISSES':<6} | {'ACCURACY':<10}")
print("-" * 60)

for row in comparison_summaries:
    label = row.get("label", "Unknown")
    counts = row.get("counts", {})
    rates = row.get("rates", {})
    
    hits = counts.get("close", 0)
    misses = counts.get("not_found", 0)
    rate = rates.get("close_rate", 0.0)
    
    # Format accuracy as a percentage
    rate_str = f"{rate:.2%}" if isinstance(rate, (int, float)) else "N/A"

    print(f"{label:<15} | {hits:<6} | {misses:<6} | {rate_str:<10}")

print("="*60)
# Out:
# === Running original REleASE batch ===
# [original] 1986-02-03_21-25.csv -> rc=0
# [original] 1986-02-05_05-50.csv -> rc=0
# [original] 1986-02-05_23-00.csv -> rc=0
# [original] 1986-02-07_01-00.csv -> rc=0
# [original] 1986-02-10_09-00.csv -> rc=0
# [original] 1986-02-14_02-20.csv -> rc=0
# [original] 1986-02-16_14-20.csv -> rc=0
# [original] 1986-03-06_06-25.csv -> rc=0
# [original] 1986-05-04_01-00.csv -> rc=0
# [original] 1987-05-29_05-25.csv -> rc=0
# [original] 1987-11-07_19-50.csv -> rc=0
# [original] 1987-12-29_14-15.csv -> rc=0
# [original] 1988-01-02_15-55.csv -> rc=0
# [original] 1988-03-25_10-50.csv -> rc=0
# [original] 1988-06-14_17-20.csv -> rc=0
# [original] 1988-06-29_23-25.csv -> rc=0
# [original] 1988-07-19_19-00.csv -> rc=0
# [original] 1988-07-26_09-40.csv -> rc=0
# [original] 1988-08-25_01-55.csv -> rc=0
# [original] 1988-09-27_09-20.csv -> rc=0
# [original] 1988-10-04_20-55.csv -> rc=0
# [original] 1988-10-11_18-45.csv -> rc=0
# [original] 1988-10-13_10-00.csv -> rc=0
# [original] 1988-11-08_01-50.csv -> rc=0
# [original] 1988-11-13_13-30.csv -> rc=0
# [original] 1988-12-12_23-10.csv -> rc=0
# [original] 1988-12-14_00-10.csv -> rc=0
# [original] 1988-12-15_21-40.csv -> rc=0
# [original] 1988-12-26_20-55.csv -> rc=0
# [original] 1988-12-28_12-45.csv -> rc=0
# [original] 1989-01-04_09-15.csv -> rc=0
# [original] 1989-03-08_05-55.csv -> rc=0
# [original] 1989-03-12_07-25.csv -> rc=0
